# %%
import io
from itertools import count
import pydotplus
import pandas as pd
import numpy as np

import networkx as nx
from networkx import Graph as NXGraph
from networkx.drawing.nx_agraph import graphviz_layout

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import collections

from IPython.display import display, Image

# %%
df = pd.read_csv('C:\\Users\\eduar\\Desktop\\trabalhobd\\champion_stats.csv')
df.loc[0,'Superclass(es)'] = 'owl:Thing'
df.head(10)
# Out:
#    Unnamed: 0           id  key  attack  defense  magic  difficulty  \
# 0           0       Aatrox  266       8        4      3           4
# 1           1         Ahri  103       3        4      8           5
# 2           2        Akali   84       5        3      8           7
# 3           3      Alistar   12       6        9      5           7
# 4           4        Amumu   32       2        6      8           3
# 5           5       Anivia   34       1        4     10          10
# 6           6        Annie    1       2        3     10           6
# 7           7     Aphelios  523       6        2      1          10
# 8           8         Ashe   22       7        3      2           4
# 9           9  AurelionSol  136       2        3      8           7
#
#                       tags      hp  hpperlevel  ...  hpregenperlevel  mpregen  \
# 0      ['Fighter', 'Tank']  580.00          90  ...             1.00    0.000
# 1     ['Mage', 'Assassin']  526.00          92  ...             0.60    8.000
# 2             ['Assassin']  575.00          95  ...             0.50   50.000
# 3      ['Tank', 'Support']  600.00         106  ...             0.85    8.500
# 4         ['Tank', 'Mage']  613.12          84  ...             0.85    7.382
# 5      ['Mage', 'Support']  480.00          82  ...             0.55    8.000
# 6                 ['Mage']  524.00          88  ...             0.55    8.000
# 7             ['Marksman']  530.00          88  ...             0.55    6.500
# 8  ['Marksman', 'Support']  570.00          87  ...             0.55    6.972
# 9                 ['Mage']  575.00          92  ...             0.60    6.000
#
#    mpregenperlevel  crit  critperlevel  attackdamage  attackdamageperlevel  \
# 0            0.000     0             0        60.000                 5.000
# 1            0.800     0             0        53.040                 3.000
# 2            0.000     0             0        62.400                 3.300
# 3            0.800     0             0        62.000                 3.750
# 4            0.525     0             0        53.380                 3.800
# 5            0.800     0             0        51.376                 3.200
# 6            0.800     0             0        50.410                 2.625
# 7            0.400     0             0        57.000                 2.000
# 8            0.400     0             0        61.000                 2.960
# 9            0.800     0             0        57.000                 3.200
#
#    attackspeedperlevel  attackspeed  Superclass(es)
# 0                2.500        0.651       owl:Thing
# 1                2.000        0.668             NaN
# 2                3.200        0.625             NaN
# 3                2.125        0.625             NaN
# 4                2.180        0.736             NaN
# 5                1.680        0.625             NaN
# 6                1.360        0.579             NaN
# 7                2.100        0.640             NaN
# 8                3.330        0.658             NaN
# 9                1.360        0.625             NaN
#
# [10 rows x 29 columns]
